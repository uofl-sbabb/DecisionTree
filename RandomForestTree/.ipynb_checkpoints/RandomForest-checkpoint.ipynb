# %% [markdown]
# # Random Forest Tree:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
geopolymer_df = pd.read_csv("Artificial Intelligence-Based Life Cycle Assessment for Sustainable Geopolymer Concrete.csv")
geopolymer_df
# Out:
#     Composition  Ground Granulated Blast-Furnace Slag  Sugarcane Bagasse Ash  \
# 0           NaN                                   NaN                    NaN
# 1           1.0                                  66.0                   19.0
# 2           2.0                                  68.0                   17.0
# 3           3.0                                  70.0                   15.0
# 4           4.0                                  72.0                   13.0
# ..          ...                                   ...                    ...
# 56         56.0                                  59.0                   13.0
# 57         57.0                                  58.0                   13.5
# 58         58.0                                  57.0                   14.0
# 59         59.0                                  56.0                   14.5
# 60         60.0                                  55.0                   15.0
#
#     Banana Peel Ash  sodium silicate  sodium sulphate  IST(min)  FST(min)  \
# 0               NaN              NaN              NaN       NaN       NaN
# 1               0.0              7.5              7.5       NaN       NaN
# 2               0.0              7.5              7.5       NaN       NaN
# 3               0.0              7.5              7.5       NaN       NaN
# 4               0.0              7.5              7.5       NaN       NaN
# ..              ...              ...              ...       ...       ...
# 56             13.0              7.5              7.5       NaN       NaN
# 57             13.5              7.5              7.5       NaN       NaN
# 58             14.0              7.5              7.5       NaN       NaN
# 59             14.5              7.5              7.5       NaN       NaN
# 60             15.0              7.5              7.5       NaN       NaN
#
#    Comprehensive Strength    Unnamed: 9    Unnamed: 10  \
# 0            3 days (psi)  7 days (psi)  28 days (psi)
# 1                     NaN           NaN            NaN
# 2                     NaN           NaN            NaN
# 3                     NaN           NaN            NaN
# 4                     NaN           NaN            NaN
# ..                    ...           ...            ...
# 56                    NaN           NaN            NaN
# 57                    NaN           NaN            NaN
# 58                    NaN           NaN            NaN
# 59                    NaN           NaN            NaN
# 60                    NaN           NaN            NaN
#
#                        Unnamed: 11  FS
# 0   170 degrees for 24 hours (psi) NaN
# 1                              NaN NaN
# 2                              NaN NaN
# 3                              NaN NaN
# 4                              NaN NaN
# ..                             ...  ..
# 56                             NaN NaN
# 57                             NaN NaN
# 58                             NaN NaN
# 59                             NaN NaN
# 60                             NaN NaN
#
# [61 rows x 13 columns]

# %%
geopolymer_df = geopolymer_df.rename(columns={'Unnamed: 9': 'Comprehensive Strength 7 days(psi)', 'Unnamed: 10': 'Comprehensive Strength 28 days(psi)', 'Unnamed: 11': '170 degrees for 24 hours(psi)'})
geopolymer_df
# Out:
#     Composition  Ground Granulated Blast-Furnace Slag  Sugarcane Bagasse Ash  \
# 0           NaN                                   NaN                    NaN
# 1           1.0                                  66.0                   19.0
# 2           2.0                                  68.0                   17.0
# 3           3.0                                  70.0                   15.0
# 4           4.0                                  72.0                   13.0
# ..          ...                                   ...                    ...
# 56         56.0                                  59.0                   13.0
# 57         57.0                                  58.0                   13.5
# 58         58.0                                  57.0                   14.0
# 59         59.0                                  56.0                   14.5
# 60         60.0                                  55.0                   15.0
#
#     Banana Peel Ash  sodium silicate  sodium sulphate  IST(min)  FST(min)  \
# 0               NaN              NaN              NaN       NaN       NaN
# 1               0.0              7.5              7.5       NaN       NaN
# 2               0.0              7.5              7.5       NaN       NaN
# 3               0.0              7.5              7.5       NaN       NaN
# 4               0.0              7.5              7.5       NaN       NaN
# ..              ...              ...              ...       ...       ...
# 56             13.0              7.5              7.5       NaN       NaN
# 57             13.5              7.5              7.5       NaN       NaN
# 58             14.0              7.5              7.5       NaN       NaN
# 59             14.5              7.5              7.5       NaN       NaN
# 60             15.0              7.5              7.5       NaN       NaN
#
#    Comprehensive Strength Comprehensive Strength 7 days(psi)  \
# 0            3 days (psi)                       7 days (psi)
# 1                     NaN                                NaN
# 2                     NaN                                NaN
# 3                     NaN                                NaN
# 4                     NaN                                NaN
# ..                    ...                                ...
# 56                    NaN                                NaN
# 57                    NaN                                NaN
# 58                    NaN                                NaN
# 59                    NaN                                NaN
# 60                    NaN                                NaN
#
#    Comprehensive Strength 28 days(psi)   170 degrees for 24 hours(psi)  FS
# 0                        28 days (psi)  170 degrees for 24 hours (psi) NaN
# 1                                  NaN                             NaN NaN
# 2                                  NaN                             NaN NaN
# 3                                  NaN                             NaN NaN
# 4                                  NaN                             NaN NaN
# ..                                 ...                             ...  ..
# 56                                 NaN                             NaN NaN
# 57                                 NaN                             NaN NaN
# 58                                 NaN                             NaN NaN
# 59                                 NaN                             NaN NaN
# 60                                 NaN                             NaN NaN
#
# [61 rows x 13 columns]

# %%
geopolymer_df.drop(geopolymer_df.index[0], inplace=True) 
geopolymer_df
# Out:
#     Composition  Ground Granulated Blast-Furnace Slag  Sugarcane Bagasse Ash  \
# 1           1.0                                  66.0                   19.0
# 2           2.0                                  68.0                   17.0
# 3           3.0                                  70.0                   15.0
# 4           4.0                                  72.0                   13.0
# 5           5.0                                  74.0                   11.0
# 6           6.0                                  76.0                    9.0
# 7           7.0                                  78.0                    7.0
# 8           8.0                                  80.0                    5.0
# 9           9.0                                  82.0                    3.0
# 10         10.0                                  84.0                    1.0
# 11         11.0                                  66.0                    0.0
# 12         12.0                                  68.0                    0.0
# 13         13.0                                  70.0                    0.0
# 14         14.0                                  72.0                    0.0
# 15         15.0                                  74.0                    0.0
# 16         16.0                                  76.0                    0.0
# 17         17.0                                  78.0                    0.0
# 18         18.0                                  80.0                    0.0
# 19         19.0                                  82.0                    0.0
# 20         20.0                                  84.0                    0.0
# 21         21.0                                  66.0                    9.5
# 22         22.0                                  68.0                    8.5
# 23         23.0                                  70.0                    7.5
# 24         24.0                                  72.0                    6.5
# 25         25.0                                  74.0                    5.5
# 26         26.0                                  76.0                    4.5
# 27         27.0                                  78.0                    3.5
# 28         28.0                                  80.0                    2.5
# 29         29.0                                  82.0                    1.5
# 30         30.0                                  84.0                    0.5
# 31         31.0                                  64.0                   21.0
# 32         32.0                                  63.0                   22.0
# 33         33.0                                  62.0                   23.0
# 34         34.0                                  61.0                   24.0
# 35         35.0                                  60.0                   25.0
# 36         36.0                                  59.0                   26.0
# 37         37.0                                  58.0                   27.0
# 38         38.0                                  57.0                   28.0
# 39         39.0                                  56.0                   29.0
# 40         40.0                                  55.0                   30.0
# 41         41.0                                  64.0                    0.0
# 42         42.0                                  63.0                    0.0
# 43         43.0                                  62.0                    0.0
# 44         44.0                                  61.0                    0.0
# 45         45.0                                  60.0                    0.0
# 46         46.0                                  59.0                    0.0
# 47         47.0                                  58.0                    0.0
# 48         48.0                                  57.0                    0.0
# 49         49.0                                  56.0                    0.0
# 50         50.0                                  55.0                    0.0
# 51         51.0                                  64.0                   10.5
# 52         52.0                                  63.0                   11.0
# 53         53.0                                  62.0                   11.5
# 54         54.0                                  61.0                   12.0
# 55         55.0                                  60.0                   12.5
# 56         56.0                                  59.0                   13.0
# 57         57.0                                  58.0                   13.5
# 58         58.0                                  57.0                   14.0
# 59         59.0                                  56.0                   14.5
# 60         60.0                                  55.0                   15.0
#
#     Banana Peel Ash  sodium silicate  sodium sulphate  IST(min)  FST(min)  \
# 1               0.0              7.5              7.5       NaN       NaN
# 2               0.0              7.5              7.5       NaN       NaN
# 3               0.0              7.5              7.5       NaN       NaN
# 4               0.0              7.5              7.5       NaN       NaN
# 5               0.0              7.5              7.5       NaN       NaN
# 6               0.0              7.5              7.5       NaN       NaN
# 7               0.0              7.5              7.5       NaN       NaN
# 8               0.0              7.5              7.5       NaN       NaN
# 9               0.0              7.5              7.5       NaN       NaN
# 10              0.0              7.5              7.5       NaN       NaN
# 11             19.0              7.5              7.5       NaN       NaN
# 12             17.0              7.5              7.5       NaN       NaN
# 13             15.0              7.5              7.5       NaN       NaN
# 14             13.0              7.5              7.5       NaN       NaN
# 15             11.0              7.5              7.5       NaN       NaN
# 16              9.0              7.5              7.5       NaN       NaN
# 17              7.0              7.5              7.5       NaN       NaN
# 18              5.0              7.5              7.5       NaN       NaN
# 19              3.0              7.5              7.5       NaN       NaN
# 20              1.0              7.5              7.5       NaN       NaN
# 21              9.5              7.5              7.5       NaN       NaN
# 22              8.5              7.5              7.5       NaN       NaN
# 23              7.5              7.5              7.5       NaN       NaN
# 24              6.5              7.5              7.5       NaN       NaN
# 25              5.5              7.5              7.5       NaN       NaN
# 26              4.5              7.5              7.5       NaN       NaN
# 27              3.5              7.5              7.5       NaN       NaN
# 28              2.5              7.5              7.5       NaN       NaN
# 29              1.5              7.5              7.5       NaN       NaN
# 30              0.5              7.5              7.5       NaN       NaN
# 31              0.0              7.5              7.5       NaN       NaN
# 32              0.0              7.5              7.5       NaN       NaN
# 33              0.0              7.5              7.5       NaN       NaN
# 34              0.0              7.5              7.5       NaN       NaN
# 35              0.0              7.5              7.5       NaN       NaN
# 36              0.0              7.5              7.5       NaN       NaN
# 37              0.0              7.5              7.5       NaN       NaN
# 38              0.0              7.5              7.5       NaN       NaN
# 39              0.0              7.5              7.5       NaN       NaN
# 40              0.0              7.5              7.5       NaN       NaN
# 41             21.0              7.5              7.5       NaN       NaN
# 42             22.0              7.5              7.5       NaN       NaN
# 43             23.0              7.5              7.5       NaN       NaN
# 44             24.0              7.5              7.5       NaN       NaN
# 45             25.0              7.5              7.5       NaN       NaN
# 46             26.0              7.5              7.5       NaN       NaN
# 47             27.0              7.5              7.5       NaN       NaN
# 48             28.0              7.5              7.5       NaN       NaN
# 49             29.0              7.5              7.5       NaN       NaN
# 50             30.0              7.5              7.5       NaN       NaN
# 51             10.5              7.5              7.5       NaN       NaN
# 52             11.0              7.5              7.5       NaN       NaN
# 53             11.5              7.5              7.5       NaN       NaN
# 54             12.0              7.5              7.5       NaN       NaN
# 55             12.5              7.5              7.5       NaN       NaN
# 56             13.0              7.5              7.5       NaN       NaN
# 57             13.5              7.5              7.5       NaN       NaN
# 58             14.0              7.5              7.5       NaN       NaN
# 59             14.5              7.5              7.5       NaN       NaN
# 60             15.0              7.5              7.5       NaN       NaN
#
#    Comprehensive Strength Comprehensive Strength 7 days(psi)  \
# 1                     NaN                                NaN
# 2                     NaN                                NaN
# 3                     NaN                                NaN
# 4                     NaN                                NaN
# 5                     NaN                                NaN
# 6                     NaN                                NaN
# 7                     NaN                                NaN
# 8                     NaN                                NaN
# 9                     NaN                                NaN
# 10                    NaN                                NaN
# 11                    NaN                                NaN
# 12                    NaN                                NaN
# 13                    NaN                                NaN
# 14                    NaN                                NaN
# 15                    NaN                                NaN
# 16                    NaN                                NaN
# 17                    NaN                                NaN
# 18                    NaN                                NaN
# 19                    NaN                                NaN
# 20                    NaN                                NaN
# 21                    NaN                                NaN
# 22                    NaN                                NaN
# 23                    NaN                                NaN
# 24                    NaN                                NaN
# 25                    NaN                                NaN
# 26                    NaN                                NaN
# 27                    NaN                                NaN
# 28                    NaN                                NaN
# 29                    NaN                                NaN
# 30                    NaN                                NaN
# 31                    NaN                                NaN
# 32                    NaN                                NaN
# 33                    NaN                                NaN
# 34                    NaN                                NaN
# 35                    NaN                                NaN
# 36                    NaN                                NaN
# 37                    NaN                                NaN
# 38                    NaN                                NaN
# 39                    NaN                                NaN
# 40                    NaN                                NaN
# 41                    NaN                                NaN
# 42                    NaN                                NaN
# 43                    NaN                                NaN
# 44                    NaN                                NaN
# 45                    NaN                                NaN
# 46                    NaN                                NaN
# 47                    NaN                                NaN
# 48                    NaN                                NaN
# 49                    NaN                                NaN
# 50                    NaN                                NaN
# 51                    NaN                                NaN
# 52                    NaN                                NaN
# 53                    NaN                                NaN
# 54                    NaN                                NaN
# 55                    NaN                                NaN
# 56                    NaN                                NaN
# 57                    NaN                                NaN
# 58                    NaN                                NaN
# 59                    NaN                                NaN
# 60                    NaN                                NaN
#
#    Comprehensive Strength 28 days(psi) 170 degrees for 24 hours(psi)  FS
# 1                                  NaN                           NaN NaN
# 2                                  NaN                           NaN NaN
# 3                                  NaN                           NaN NaN
# 4                                  NaN                           NaN NaN
# 5                                  NaN                           NaN NaN
# 6                                  NaN                           NaN NaN
# 7                                  NaN                           NaN NaN
# 8                                  NaN                           NaN NaN
# 9                                  NaN                           NaN NaN
# 10                                 NaN                           NaN NaN
# 11                                 NaN                           NaN NaN
# 12                                 NaN                           NaN NaN
# 13                                 NaN                           NaN NaN
# 14                                 NaN                           NaN NaN
# 15                                 NaN                           NaN NaN
# 16                                 NaN                           NaN NaN
# 17                                 NaN                           NaN NaN
# 18                                 NaN                           NaN NaN
# 19                                 NaN                           NaN NaN
# 20                                 NaN                           NaN NaN
# 21                                 NaN                           NaN NaN
# 22                                 NaN                           NaN NaN
# 23                                 NaN                           NaN NaN
# 24                                 NaN                           NaN NaN
# 25                                 NaN                           NaN NaN
# 26                                 NaN                           NaN NaN
# 27                                 NaN                           NaN NaN
# 28                                 NaN                           NaN NaN
# 29                                 NaN                           NaN NaN
# 30                                 NaN                           NaN NaN
# 31                                 NaN                           NaN NaN
# 32                                 NaN                           NaN NaN
# 33                                 NaN                           NaN NaN
# 34                                 NaN                           NaN NaN
# 35                                 NaN                           NaN NaN
# 36                                 NaN                           NaN NaN
# 37                                 NaN                           NaN NaN
# 38                                 NaN                           NaN NaN
# 39                                 NaN                           NaN NaN
# 40                                 NaN                           NaN NaN
# 41                                 NaN                           NaN NaN
# 42                                 NaN                           NaN NaN
# 43                                 NaN                           NaN NaN
# 44                                 NaN                           NaN NaN
# 45                                 NaN                           NaN NaN
# 46                                 NaN                           NaN NaN
# 47                                 NaN                           NaN NaN
# 48                                 NaN                           NaN NaN
# 49                                 NaN                           NaN NaN
# 50                                 NaN                           NaN NaN
# 51                                 NaN                           NaN NaN
# 52                                 NaN                           NaN NaN
# 53                                 NaN                           NaN NaN
# 54                                 NaN                           NaN NaN
# 55                                 NaN                           NaN NaN
# 56                                 NaN                           NaN NaN
# 57                                 NaN                           NaN NaN
# 58                                 NaN                           NaN NaN
# 59                                 NaN                           NaN NaN
# 60                                 NaN                           NaN NaN

# %% [markdown]
# # Input Values:

# %%
geopolymer_df.head()
# Out:
#    Composition  Ground Granulated Blast-Furnace Slag  Sugarcane Bagasse Ash  \
# 1          1.0                                  66.0                   19.0
# 2          2.0                                  68.0                   17.0
# 3          3.0                                  70.0                   15.0
# 4          4.0                                  72.0                   13.0
# 5          5.0                                  74.0                   11.0
#
#    Banana Peel Ash  sodium silicate  sodium sulphate  IST(min)  FST(min)  \
# 1              0.0              7.5              7.5       NaN       NaN
# 2              0.0              7.5              7.5       NaN       NaN
# 3              0.0              7.5              7.5       NaN       NaN
# 4              0.0              7.5              7.5       NaN       NaN
# 5              0.0              7.5              7.5       NaN       NaN
#
#   Comprehensive Strength Comprehensive Strength 7 days(psi)  \
# 1                    NaN                                NaN
# 2                    NaN                                NaN
# 3                    NaN                                NaN
# 4                    NaN                                NaN
# 5                    NaN                                NaN
#
#   Comprehensive Strength 28 days(psi) 170 degrees for 24 hours(psi)  FS
# 1                                 NaN                           NaN NaN
# 2                                 NaN                           NaN NaN
# 3                                 NaN                           NaN NaN
# 4                                 NaN                           NaN NaN
# 5                                 NaN                           NaN NaN

# %%
mask_ist = geopolymer_df['IST(min)'].isna()
geopolymer_df.loc[mask_ist, 'IST(min)'] = np.random.uniform(low=30, high=80, size=mask_ist.sum())
geopolymer_df['IST(min)'] = geopolymer_df['IST(min)'].astype(int)

mask_fst = geopolymer_df['FST(min)'].isna()
geopolymer_df.loc[mask_fst, 'FST(min)'] = np.random.uniform(low=30, high=80, size=mask_fst.sum())
geopolymer_df['FST(min)'] = geopolymer_df['FST(min)'].astype(int)

mask_low_cs = geopolymer_df['Comprehensive Strength'].isna()
geopolymer_df.loc[mask_low_cs, 'Comprehensive Strength'] = np.random.uniform(low=10, high=20, size=mask_low_cs.sum())
geopolymer_df['Comprehensive Strength'] = geopolymer_df['Comprehensive Strength'].astype(int)

mask_medium_cs = geopolymer_df['Comprehensive Strength 7 days(psi)'].isna()
geopolymer_df.loc[mask_medium_cs, 'Comprehensive Strength 7 days(psi)'] = np.random.uniform(low=15, high=35, size=mask_medium_cs.sum())
geopolymer_df['Comprehensive Strength 7 days(psi)'] = geopolymer_df['Comprehensive Strength 7 days(psi)'].astype(int)

mask_high_cs = geopolymer_df['Comprehensive Strength 28 days(psi)'].isna()
geopolymer_df.loc[mask_high_cs, 'Comprehensive Strength 28 days(psi)'] = np.random.uniform(low=45, high=80, size=mask_high_cs.sum())
geopolymer_df['Comprehensive Strength 28 days(psi)'] = geopolymer_df['Comprehensive Strength 28 days(psi)'].astype(int)

mask_170_degrees = geopolymer_df['170 degrees for 24 hours(psi)'].isna()
geopolymer_df.loc[mask_170_degrees, '170 degrees for 24 hours(psi)'] = np.random.uniform(low=25, high=40, size=mask_170_degrees.sum())
geopolymer_df['170 degrees for 24 hours(psi)'] = geopolymer_df['170 degrees for 24 hours(psi)'].astype(int)

mask_fs = geopolymer_df['FS'].isna()
geopolymer_df.loc[mask_fs, 'FS'] = np.random.uniform(low=15, high=35, size=mask_fs.sum())
geopolymer_df['FS'] = geopolymer_df['FS'].astype(int)

geopolymer_df.head()
# Out:
# C:\Users\sydne\AppData\Local\Temp\ipykernel_18924\3616810849.py:10: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   geopolymer_df.loc[mask_low_cs, 'Comprehensive Strength'] = np.random.uniform(low=10, high=20, size=mask_low_cs.sum())
# C:\Users\sydne\AppData\Local\Temp\ipykernel_18924\3616810849.py:14: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   geopolymer_df.loc[mask_medium_cs, 'Comprehensive Strength 7 days(psi)'] = np.random.uniform(low=15, high=35, size=mask_medium_cs.sum())
# C:\Users\sydne\AppData\Local\Temp\ipykernel_18924\3616810849.py:18: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   geopolymer_df.loc[mask_high_cs, 'Comprehensive Strength 28 days(psi)'] = np.random.uniform(low=45, high=80, size=mask_high_cs.sum())
# C:\Users\sydne\AppData\Local\Temp\ipykernel_18924\3616810849.py:22: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   geopolymer_df.loc[mask_170_degrees, '170 degrees for 24 hours(psi)'] = np.random.uniform(low=25, high=40, size=mask_170_degrees.sum())
#    Composition  Ground Granulated Blast-Furnace Slag  Sugarcane Bagasse Ash  \
# 1          1.0                                  66.0                   19.0
# 2          2.0                                  68.0                   17.0
# 3          3.0                                  70.0                   15.0
# 4          4.0                                  72.0                   13.0
# 5          5.0                                  74.0                   11.0
#
#    Banana Peel Ash  sodium silicate  sodium sulphate  IST(min)  FST(min)  \
# 1              0.0              7.5              7.5        42        78
# 2              0.0              7.5              7.5        67        45
# 3              0.0              7.5              7.5        58        50
# 4              0.0              7.5              7.5        78        36
# 5              0.0              7.5              7.5        34        72
#
#    Comprehensive Strength  Comprehensive Strength 7 days(psi)  \
# 1                      19                                  19
# 2                      19                                  32
# 3                      18                                  26
# 4                      12                                  25
# 5                      17                                  24
#
#    Comprehensive Strength 28 days(psi)  170 degrees for 24 hours(psi)  FS
# 1                                   70                             35  20
# 2                                   67                             30  27
# 3                                   59                             32  16
# 4                                   46                             28  15
# 5                                   75                             32  24

# %%
# summary of stats:
geopolymer_df.describe()
# Out:
#        Composition  Ground Granulated Blast-Furnace Slag  \
# count    60.000000                             60.000000
# mean     30.500000                             67.250000
# std      17.464249                              9.058426
# min       1.000000                             55.000000
# 25%      15.750000                             59.750000
# 50%      30.500000                             65.000000
# 75%      45.250000                             74.500000
# max      60.000000                             84.000000
#
#        Sugarcane Bagasse Ash  Banana Peel Ash  sodium silicate  \
# count              60.000000        60.000000             60.0
# mean                8.875000         8.875000              7.5
# std                 9.358955         9.358955              0.0
# min                 0.000000         0.000000              7.5
# 25%                 0.000000         0.000000              7.5
# 50%                 6.750000         6.750000              7.5
# 75%                14.125000        14.125000              7.5
# max                30.000000        30.000000              7.5
#
#        sodium sulphate   IST(min)   FST(min)  Comprehensive Strength  \
# count             60.0  60.000000  60.000000               60.000000
# mean               7.5  55.250000  57.150000               14.466667
# std                0.0  13.352617  16.007228                2.994156
# min                7.5  32.000000  30.000000               10.000000
# 25%                7.5  44.500000  44.500000               12.000000
# 50%                7.5  55.500000  60.500000               14.000000
# 75%                7.5  66.250000  72.000000               17.250000
# max                7.5  79.000000  79.000000               19.000000
#
#        Comprehensive Strength 7 days(psi)  \
# count                             60.0000
# mean                              23.5500
# std                                5.5797
# min                               15.0000
# 25%                               18.0000
# 50%                               24.0000
# 75%                               28.0000
# max                               33.0000
#
#        Comprehensive Strength 28 days(psi)  170 degrees for 24 hours(psi)  \
# count                            60.000000                      60.000000
# mean                             61.766667                      32.383333
# std                              10.998254                       4.392180
# min                              45.000000                      25.000000
# 25%                              52.750000                      28.000000
# 50%                              59.000000                      32.000000
# 75%                              72.000000                      36.000000
# max                              79.000000                      39.000000
#
#               FS
# count  60.000000
# mean   24.066667
# std     6.117124
# min    15.000000
# 25%    19.000000
# 50%    24.000000
# 75%    29.000000
# max    34.000000

# %% [markdown]
# # Train and Test Data:

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
X = geopolymer_df.iloc[:, 1:6]
y = geopolymer_df.iloc[:, 6:13]

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Create and train the model
# Key parameters include n_estimators (number of trees) and random_state for reproducibility
rf = RandomForestRegressor(n_estimators=100, random_state=42) 
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Make predictions on the test set
predictions = rf.predict(X_test)
predictions
# Out:
# array([[50.32, 41.3 , 14.97, 29.25, 56.6 , 30.26, 25.71],
#        [49.37, 57.01, 15.34, 21.32, 66.41, 32.55, 26.42],
#        [59.46, 57.25, 14.49, 19.6 , 61.78, 34.  , 25.62],
#        [53.6 , 70.5 , 15.  , 26.09, 62.51, 32.67, 24.42],
#        [53.33, 47.56, 14.21, 17.73, 53.75, 33.85, 25.23],
#        [50.15, 59.04, 16.26, 23.5 , 59.92, 30.87, 20.2 ],
#        [59.95, 53.31, 11.92, 20.99, 62.96, 32.13, 20.33],
#        [59.38, 67.82, 14.84, 28.01, 68.26, 30.49, 27.14],
#        [61.73, 51.57, 16.54, 18.38, 53.79, 32.15, 27.44],
#        [63.99, 49.74, 15.02, 23.27, 61.64, 33.72, 23.95],
#        [62.08, 64.49, 14.92, 26.74, 67.83, 29.69, 26.5 ],
#        [48.96, 68.54, 14.72, 21.29, 56.15, 33.24, 19.53],
#        [50.31, 47.97, 11.67, 23.94, 58.26, 29.92, 22.7 ],
#        [50.66, 58.37, 16.53, 24.19, 66.87, 32.63, 22.23],
#        [47.93, 64.52, 15.6 , 23.39, 56.56, 31.2 , 18.65],
#        [62.76, 65.1 , 12.44, 21.97, 58.28, 32.19, 24.09],
#        [67.67, 61.75, 14.99, 26.36, 70.76, 30.61, 27.55],
#        [54.78, 50.65, 14.51, 19.19, 66.2 , 32.41, 27.43]])

# %%
# Evaluate the model
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)
print(f"Mean Squared Error: {mse}") 
print(f"R^2 Error: {r2}")
# Out:
# Mean Squared Error: 143.07931507936505
# R^2 Error: -0.40347016392831214

# %%
# predicted values in dataframe
df_pred = pd.DataFrame(
    predictions,
    columns=y.columns,
)

df_pred
# Out:
#     IST(min)  FST(min)  Comprehensive Strength  \
# 0      50.32     41.30                   14.97
# 1      49.37     57.01                   15.34
# 2      59.46     57.25                   14.49
# 3      53.60     70.50                   15.00
# 4      53.33     47.56                   14.21
# 5      50.15     59.04                   16.26
# 6      59.95     53.31                   11.92
# 7      59.38     67.82                   14.84
# 8      61.73     51.57                   16.54
# 9      63.99     49.74                   15.02
# 10     62.08     64.49                   14.92
# 11     48.96     68.54                   14.72
# 12     50.31     47.97                   11.67
# 13     50.66     58.37                   16.53
# 14     47.93     64.52                   15.60
# 15     62.76     65.10                   12.44
# 16     67.67     61.75                   14.99
# 17     54.78     50.65                   14.51
#
#     Comprehensive Strength 7 days(psi)  Comprehensive Strength 28 days(psi)  \
# 0                                29.25                                56.60
# 1                                21.32                                66.41
# 2                                19.60                                61.78
# 3                                26.09                                62.51
# 4                                17.73                                53.75
# 5                                23.50                                59.92
# 6                                20.99                                62.96
# 7                                28.01                                68.26
# 8                                18.38                                53.79
# 9                                23.27                                61.64
# 10                               26.74                                67.83
# 11                               21.29                                56.15
# 12                               23.94                                58.26
# 13                               24.19                                66.87
# 14                               23.39                                56.56
# 15                               21.97                                58.28
# 16                               26.36                                70.76
# 17                               19.19                                66.20
#
#     170 degrees for 24 hours(psi)     FS
# 0                           30.26  25.71
# 1                           32.55  26.42
# 2                           34.00  25.62
# 3                           32.67  24.42
# 4                           33.85  25.23
# 5                           30.87  20.20
# 6                           32.13  20.33
# 7                           30.49  27.14
# 8                           32.15  27.44
# 9                           33.72  23.95
# 10                          29.69  26.50
# 11                          33.24  19.53
# 12                          29.92  22.70
# 13                          32.63  22.23
# 14                          31.20  18.65
# 15                          32.19  24.09
# 16                          30.61  27.55
# 17                          32.41  27.43

# %% [markdown]
# # Feature Importance:

# %%
feature_importance_df = pd.DataFrame({
    "feature": X_test.columns,
    "importance": model.feature_importances_
})
feature_importance_df
# Out:
#                                 feature  importance
# 0  Ground Granulated Blast-Furnace Slag    0.406311
# 1                 Sugarcane Bagasse Ash    0.273292
# 2                       Banana Peel Ash    0.320396
# 3                       sodium silicate    0.000000
# 4                       sodium sulphate    0.000000
